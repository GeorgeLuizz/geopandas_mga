# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data = gpd.read_file('dados/PR_Municipios_2021.shp')
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head(5)
# Out:
#     CD_MUN               NM_MUN SIGLA  AREA_KM2  \
# 0  4100103               Abatiá    PR   228.717
# 1  4100202         Adrianópolis    PR  1349.311
# 2  4100301        Agudos do Sul    PR   192.261
# 3  4100400  Almirante Tamandaré    PR   194.888
# 4  4100459   Altamira do Paraná    PR   386.945
#
#                                             geometry
# 0  POLYGON ((-50.22465 -23.22603, -50.22561 -23.2...
# 1  POLYGON ((-48.99969 -24.63712, -48.99927 -24.6...
# 2  POLYGON ((-49.30433 -25.94769, -49.30541 -25.9...
# 3  POLYGON ((-49.28261 -25.22827, -49.28076 -25.2...
# 4  POLYGON ((-52.81511 -24.71726, -52.80995 -24.7...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot(figsize=(16, 14), facecolor='white', edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
gdf_mga = data[data['NM_MUN'] == 'Maringá']
gdf_mga
# Out:
#       CD_MUN   NM_MUN SIGLA  AREA_KM2  \
# 208  4115200  Maringá    PR   487.012
#
#                                               geometry
# 208  POLYGON ((-51.96547 -23.25447, -51.96438 -23.2...

# %%
gdf_mga.plot(figsize=(8, 8), facecolor='white', edgecolor='black')
plt.show()

# %%
filename = "dados/maringa.json"
gdf_mga.to_file(filename, driver="GeoJSON")

# %%
gdf_mga = gpd.read_file(filename, driver="GeoJSON")
gdf_mga
# Out:
#     CD_MUN   NM_MUN SIGLA  AREA_KM2  \
# 0  4115200  Maringá    PR   487.012
#
#                                             geometry
# 0  POLYGON ((-51.96547 -23.25447, -51.96438 -23.2...

# %%
from shapely.geometry import Point, LineString, Polygon

# %%
ponto_1 = Point(2,3)
ponto_2 = Point(5,7)

distancia = ponto_1.distance(ponto_2)

print(distancia)
# Out:
# 5.0

# %%
ponto_1 = Point(2,3)
ponto_2 = Point(5,7)
ponto_3 = Point(2,10)

linha = LineString([ponto_1, ponto_2, ponto_3])

# %%
linha

# %%
print(linha)
# Out:
# LINESTRING (2 3, 5 7, 2 10)

# %%
type(linha)
# Out:
# shapely.geometry.linestring.LineString

# %%
list(linha.coords)
# Out:
# [(2.0, 3.0), (5.0, 7.0), (2.0, 10.0)]

# %%
cordenadas_x = list(linha.xy[0])
cordenadas_y = list(linha.xy[1])
print('cordenadas_x:', cordenadas_x)
print('cordenadas_y:', cordenadas_y)
# Out:
# cordenadas_x: [2.0, 5.0, 2.0]
# cordenadas_y: [3.0, 7.0, 10.0]

# %%
linha.length
# Out:
# 9.242640687119284

# %%
linha.centroid

# %%
poly = Polygon([(2,3),(5,7),(2,10)])

# %%
poly

# %%
poly_area = poly.area

print(poly_area)
# Out:
# 10.5
